// %%
USE{
    dependencies {
        implementation("guru.nidi:graphviz-kotlin:0.18.1")
    }
}

// %%
import guru.nidi.graphviz.KraphvizContext
import guru.nidi.graphviz.attribute.Arrow
import guru.nidi.graphviz.attribute.Attributes
import guru.nidi.graphviz.attribute.Label
import guru.nidi.graphviz.engine.Format
import guru.nidi.graphviz.engine.Graphviz
import guru.nidi.graphviz.graph
import guru.nidi.graphviz.model.CreationContext
import guru.nidi.graphviz.model.Graph
import guru.nidi.graphviz.model.Link
import guru.nidi.graphviz.model.LinkSource
import guru.nidi.graphviz.toGraphviz
import java.io.File
import kotlin.random.Random


val a = graph(directed = true) {
     ("a" - "b")[Label.raw("value")]
    "a" - "c"
    ("a" - "d")[Label.raw("value")]
    "b" - "a"
    "b" - "d"
    ("qgv" - "mjm")[Label.raw("OR")]
    "c" - "a"
    "c" - "d"
    "c"- "g"}

val file = Graphviz.fromGraph(a).width(700).render(Format.PNG).toFile(File("output.png"))

// %%
val input = """x00: 1
x01: 0
x02: 0
x03: 1
x04: 1
x05: 1
x06: 0
x07: 0
x08: 1
x09: 1
x10: 0
x11: 1
x12: 0
x13: 1
x14: 0
x15: 1
x16: 0
x17: 0
x18: 1
x19: 1
x20: 0
x21: 0
x22: 0
x23: 1
x24: 1
x25: 1
x26: 0
x27: 0
x28: 1
x29: 0
x30: 0
x31: 0
x32: 1
x33: 0
x34: 1
x35: 0
x36: 1
x37: 0
x38: 1
x39: 1
x40: 1
x41: 0
x42: 0
x43: 0
x44: 1
y00: 1
y01: 1
y02: 1
y03: 1
y04: 0
y05: 0
y06: 0
y07: 0
y08: 0
y09: 1
y10: 0
y11: 1
y12: 0
y13: 1
y14: 0
y15: 1
y16: 1
y17: 1
y18: 1
y19: 1
y20: 0
y21: 0
y22: 1
y23: 1
y24: 1
y25: 1
y26: 0
y27: 1
y28: 0
y29: 0
y30: 0
y31: 0
y32: 1
y33: 0
y34: 1
y35: 1
y36: 0
y37: 0
y38: 0
y39: 1
y40: 1
y41: 0
y42: 0
y43: 0
y44: 1

qgv OR dsf -> mjm
shj AND wsr -> ftr
jcf OR wgg -> chb
jbp AND grd -> tcw
rbm OR sck -> dtj
qjb OR qqm -> vdr
ktf OR pvt -> tjg
x32 XOR y32 -> wnj
nbc AND wjv -> tjm
y42 XOR x42 -> ksk
y31 XOR x31 -> mqk
y32 AND x32 -> jfp
grd XOR jbp -> z36
y39 XOR x39 -> bmb
vbj XOR chb -> z04
tqv XOR www -> z40
x34 AND y34 -> sck
y07 AND x07 -> dsf
y12 XOR x12 -> qvh
fnt AND bnk -> pvt
x10 XOR y10 -> fnt
wgw AND nph -> hjt
x30 XOR y30 -> bgs
bdm XOR hvn -> z37
mtg XOR vnm -> z06
gdn OR pck -> wsr
ttr OR nfj -> fbv
jtn AND vtk -> wqs
x08 XOR y08 -> qjb
dmm OR mmr -> nhk
qqd AND cph -> bqd
tqv AND www -> nnr
ggg XOR kbg -> z03
hff AND gdg -> twb
nqm OR whj -> ghb
x14 AND y14 -> nfj
crv XOR cvf -> z25
ftc OR jjn -> z45
bnk XOR fnt -> z10
y30 AND x30 -> mmr
qtv AND dnj -> gbg
x23 AND y23 -> vgr
ndd OR ncb -> fhg
x33 AND y33 -> qgm
rrh OR dqs -> gdp
y40 XOR x40 -> www
x41 XOR y41 -> wvq
jtn XOR vtk -> z20
tpd OR djn -> qvc
y18 AND x18 -> jdr
pnd OR hwf -> vtk
y26 AND x26 -> vqh
vcs XOR dtj -> jbp
x03 AND y03 -> wgg
rjv OR fgf -> brq
vjn AND tjg -> trg
cph XOR qqd -> z05
jbr AND ncd -> mvb
qvh AND wmd -> fbn
x25 XOR y25 -> cvf
x39 AND y39 -> rvc
y44 AND x44 -> ftc
y36 XOR x36 -> grd
y03 XOR x03 -> kbg
vvj XOR bqv -> z27
vbj AND chb -> kqr
twb OR dtd -> stw
mnv XOR hcg -> z13
y26 XOR x26 -> dnj
rkd OR rmp -> wrw
y22 XOR x22 -> tdc
wvq AND tkt -> jsc
mjm XOR gvw -> z08
hvn AND bdm -> pck
cbf XOR vdr -> z09
hdb OR hmb -> qtv
dvs OR mvd -> hwm
mqk AND nhk -> ncb
rfj OR jgc -> bst
wrw XOR hwh -> z28
gdp XOR stm -> z07
stm AND gdp -> qgv
hff XOR gdg -> z29
y44 XOR x44 -> vbd
tqq OR jjc -> tpn
qgm OR mvb -> cqg
dkg XOR ghb -> z02
wrw AND hwh -> pkq
hwm AND tdc -> z22
x02 AND y02 -> gws
jfp OR mpd -> ncd
y11 AND x11 -> smr
hvd AND bmb -> vts
kqr OR jsj -> qqd
y24 XOR x24 -> wgw
stw XOR bgs -> z30
tpn AND wcn -> tpd
y19 AND x19 -> pnd
y38 AND x38 -> dkn
pkq OR vbc -> hff
y31 AND x31 -> ndd
wwc AND nvv -> whj
y14 XOR x14 -> drk
bst AND pkj -> jjc
sht OR fhh -> bnk
x05 XOR y05 -> cph
vts OR rvc -> tqv
x04 AND y04 -> jsj
wjv XOR nbc -> z23
y17 XOR x17 -> wcn
x04 XOR y04 -> vbj
y01 AND x01 -> nqm
x01 XOR y01 -> wwc
vdr AND cbf -> sht
jhm AND wst -> dvs
tpv XOR drk -> z14
cjm XOR rws -> z19
bqd OR hns -> mtg
x20 XOR y20 -> jtn
x08 AND y08 -> gvw
cbc XOR cqg -> z34
rgt AND fbv -> rfj
wmd XOR qvh -> z12
x23 XOR y23 -> wjv
y35 AND x35 -> ppf
x43 AND y43 -> trf
fhg XOR wnj -> z32
x12 AND y12 -> cmn
y00 AND x00 -> nvv
tcw OR jms -> hvn
nhk XOR mqk -> z31
x07 XOR y07 -> stm
vgr OR tjm -> nph
drk AND tpv -> ttr
x09 AND y09 -> fhh
x22 AND y22 -> snh
wgw XOR nph -> z24
mtg AND vnm -> rrh
qvc AND mms -> tps
x06 XOR y06 -> vnm
tps OR jdr -> cjm
fbv XOR rgt -> jgc
y41 AND x41 -> wfd
x19 XOR y19 -> rws
hcg AND mnv -> cfk
wsr XOR shj -> z38
brq AND jpt -> wtr
cjm AND rws -> hwf
y25 AND x25 -> hmb
y02 XOR x02 -> dkg
y40 AND x40 -> qsg
bqv AND vvj -> rmp
hvd XOR bmb -> z39
y35 XOR x35 -> vcs
x42 AND y42 -> rjv
x37 AND y37 -> gdn
tjg XOR vjn -> z11
qtv XOR dnj -> z26
jhm XOR wst -> z21
nwp OR gws -> ggg
y00 XOR x00 -> z00
mrq OR wqs -> wst
x13 AND y13 -> rsq
ftr OR dkn -> hvd
jbr XOR ncd -> z33
x05 AND y05 -> hns
rsq OR cfk -> tpv
mms XOR qvc -> z18
x27 AND y27 -> rkd
crv AND cvf -> hdb
cqg AND cbc -> rbm
pkj XOR bst -> z16
x28 AND y28 -> vbc
jsc OR wfd -> ngw
mjm AND gvw -> qqm
wnj AND fhg -> mpd
y15 XOR x15 -> rgt
x20 AND y20 -> mrq
tkt XOR wvq -> z41
y13 XOR x13 -> mnv
y24 AND x24 -> nqr
wtr OR trf -> jvs
ggg AND kbg -> jcf
x36 AND y36 -> jms
x29 AND y29 -> dtd
ksk AND ngw -> fgf
x11 XOR y11 -> vjn
tpn XOR wcn -> z17
y43 XOR x43 -> jpt
vbd AND jvs -> jjn
nnr OR qsg -> tkt
x27 XOR y27 -> bqv
x28 XOR y28 -> hwh
x09 XOR y09 -> cbf
vcs AND dtj -> qrg
x34 XOR y34 -> cbc
ghb AND dkg -> nwp
y37 XOR x37 -> bdm
x38 XOR y38 -> shj
hjt OR nqr -> crv
vbd XOR jvs -> z44
fbn OR cmn -> hcg
x06 AND y06 -> dqs
y15 AND x15 -> z15
x33 XOR y33 -> jbr
y21 XOR x21 -> jhm
snh OR drg -> nbc
y18 XOR x18 -> mms
vqh OR gbg -> vvj
y21 AND x21 -> mvd
qrg OR ppf -> z35
y10 AND x10 -> ktf
x16 AND y16 -> tqq
tdc XOR hwm -> drg
wwc XOR nvv -> z01
x17 AND y17 -> djn
jpt XOR brq -> z43
smr OR trg -> wmd
x16 XOR y16 -> pkj
x29 XOR y29 -> gdg
bgs AND stw -> dmm
ngw XOR ksk -> z42"""

// %%
val gates = input.substringAfter("\n\n").lines().map { it.split(Regex(" -> | ")) }

val list = mutableListOf<String>()
gates.forEach {
    var one = "(\"${it[0]}\" - \"${it[3]}\")[Label.raw(\"${it[1]}\")]"
    var two = "(\"${it[2]}\" - \"${it[3]}\")[Label.raw(\"${it[1]}\")]"
    list.add(one)
    list.add(two)
}

File("output").writeText(list.joinToString ("\n"))
// Out:
// [("qgv" - "mjm")[Label.raw("OR")], ("dsf" - "mjm")[Label.raw("OR")], ("shj" - "ftr")[Label.raw("AND")], ("wsr" - "ftr")[Label.raw("AND")], ("jcf" - "chb")[Label.raw("OR")], ("wgg" - "chb")[Label.raw("OR")], ("jbp" - "tcw")[Label.raw("AND")], ("grd" - "tcw")[Label.raw("AND")], ("rbm" - "dtj")[Label.raw("OR")], ("sck" - "dtj")[Label.raw("OR")], ("qjb" - "vdr")[Label.raw("OR")], ("qqm" - "vdr")[Label.raw("OR")], ("ktf" - "tjg")[Label.raw("OR")], ("pvt" - "tjg")[Label.raw("OR")], ("x32" - "wnj")[Label.raw("XOR")], ("y32" - "wnj")[Label.raw("XOR")], ("nbc" - "tjm")[Label.raw("AND")], ("wjv" - "tjm")[Label.raw("AND")], ("y42" - "ksk")[Label.raw("XOR")], ("x42" - "ksk")[Label.raw("XOR")], ("y31" - "mqk")[Label.raw("XOR")], ("x31" - "mqk")[Label.raw("XOR")], ("y32" - "jfp")[Label.raw("AND")], ("x32" - "jfp")[Label.raw("AND")], ("grd" - "z36")[Label.raw("XOR")], ("jbp" - "z36")[Label.raw("XOR")], ("y39" - "bmb")[Label.raw("XOR")], ("x39" - "bmb")[Label.raw("XOR")], ("vbj" - "z04")[Label.raw(
// ...

// %%
import guru.nidi.graphviz.model.MutableGraph


val a = graph(directed = true) {
    ("qgv" - "mjm")[Label.raw("OR")]
    ("dsf" - "mjm")[Label.raw("OR")]
    ("shj" - "ftr")[Label.raw("AND")]
    ("wsr" - "ftr")[Label.raw("AND")]
    ("jcf" - "chb")[Label.raw("OR")]
    ("wgg" - "chb")[Label.raw("OR")]
    ("jbp" - "tcw")[Label.raw("AND")]
    ("grd" - "tcw")[Label.raw("AND")]
    ("rbm" - "dtj")[Label.raw("OR")]
    ("sck" - "dtj")[Label.raw("OR")]
    ("qjb" - "vdr")[Label.raw("OR")]
    ("qqm" - "vdr")[Label.raw("OR")]
    ("ktf" - "tjg")[Label.raw("OR")]
    ("pvt" - "tjg")[Label.raw("OR")]
    ("x32" - "wnj")[Label.raw("XOR")]
    ("y32" - "wnj")[Label.raw("XOR")]
    ("nbc" - "tjm")[Label.raw("AND")]
    ("wjv" - "tjm")[Label.raw("AND")]
    ("y42" - "ksk")[Label.raw("XOR")]
    ("x42" - "ksk")[Label.raw("XOR")]
    ("y31" - "mqk")[Label.raw("XOR")]
    ("x31" - "mqk")[Label.raw("XOR")]
    ("y32" - "jfp")[Label.raw("AND")]
    ("x32" - "jfp")[Label.raw("AND")]
    ("grd" - "z36")[Label.raw("XOR")]
    ("jbp" - "z36")[Label.raw("XOR")]
    ("y39" - "bmb")[Label.raw("XOR")]
    ("x39" - "bmb")[Label.raw("XOR")]
    ("vbj" - "z04")[Label.raw("XOR")]
    ("chb" - "z04")[Label.raw("XOR")]
    ("tqv" - "z40")[Label.raw("XOR")]
    ("www" - "z40")[Label.raw("XOR")]
    ("x34" - "sck")[Label.raw("AND")]
    ("y34" - "sck")[Label.raw("AND")]
    ("y07" - "dsf")[Label.raw("AND")]
    ("x07" - "dsf")[Label.raw("AND")]
    ("y12" - "qvh")[Label.raw("XOR")]
    ("x12" - "qvh")[Label.raw("XOR")]
    ("fnt" - "pvt")[Label.raw("AND")]
    ("bnk" - "pvt")[Label.raw("AND")]
    ("x10" - "fnt")[Label.raw("XOR")]
    ("y10" - "fnt")[Label.raw("XOR")]
    ("wgw" - "hjt")[Label.raw("AND")]
    ("nph" - "hjt")[Label.raw("AND")]
    ("x30" - "bgs")[Label.raw("XOR")]
    ("y30" - "bgs")[Label.raw("XOR")]
    ("bdm" - "z37")[Label.raw("XOR")]
    ("hvn" - "z37")[Label.raw("XOR")]
    ("mtg" - "z06")[Label.raw("XOR")]
    ("vnm" - "z06")[Label.raw("XOR")]
    ("gdn" - "wsr")[Label.raw("OR")]
    ("pck" - "wsr")[Label.raw("OR")]
    ("ttr" - "fbv")[Label.raw("OR")]
    ("nfj" - "fbv")[Label.raw("OR")]
    ("jtn" - "wqs")[Label.raw("AND")]
    ("vtk" - "wqs")[Label.raw("AND")]
    ("x08" - "qjb")[Label.raw("XOR")]
    ("y08" - "qjb")[Label.raw("XOR")]
    ("dmm" - "nhk")[Label.raw("OR")]
    ("mmr" - "nhk")[Label.raw("OR")]
    ("qqd" - "bqd")[Label.raw("AND")]
    ("cph" - "bqd")[Label.raw("AND")]
    ("tqv" - "nnr")[Label.raw("AND")]
    ("www" - "nnr")[Label.raw("AND")]
    ("ggg" - "z03")[Label.raw("XOR")]
    ("kbg" - "z03")[Label.raw("XOR")]
    ("hff" - "twb")[Label.raw("AND")]
    ("gdg" - "twb")[Label.raw("AND")]
    ("nqm" - "ghb")[Label.raw("OR")]
    ("whj" - "ghb")[Label.raw("OR")]
    ("x14" - "nfj")[Label.raw("AND")]
    ("y14" - "nfj")[Label.raw("AND")]
    ("crv" - "z25")[Label.raw("XOR")]
    ("cvf" - "z25")[Label.raw("XOR")]
    ("ftc" - "z45")[Label.raw("OR")]
    ("jjn" - "z45")[Label.raw("OR")]
    ("bnk" - "z10")[Label.raw("XOR")]
    ("fnt" - "z10")[Label.raw("XOR")]
    ("y30" - "mmr")[Label.raw("AND")]
    ("x30" - "mmr")[Label.raw("AND")]
    ("qtv" - "gbg")[Label.raw("AND")]
    ("dnj" - "gbg")[Label.raw("AND")]
    ("x23" - "vgr")[Label.raw("AND")]
    ("y23" - "vgr")[Label.raw("AND")]
    ("ndd" - "fhg")[Label.raw("OR")]
    ("ncb" - "fhg")[Label.raw("OR")]
    ("x33" - "qgm")[Label.raw("AND")]
    ("y33" - "qgm")[Label.raw("AND")]
    ("rrh" - "gdp")[Label.raw("OR")]
    ("dqs" - "gdp")[Label.raw("OR")]
    ("y40" - "www")[Label.raw("XOR")]
    ("x40" - "www")[Label.raw("XOR")]
    ("x41" - "wvq")[Label.raw("XOR")]
    ("y41" - "wvq")[Label.raw("XOR")]
    ("jtn" - "z20")[Label.raw("XOR")]
    ("vtk" - "z20")[Label.raw("XOR")]
    ("tpd" - "qvc")[Label.raw("OR")]
    ("djn" - "qvc")[Label.raw("OR")]
    ("y18" - "jdr")[Label.raw("AND")]
    ("x18" - "jdr")[Label.raw("AND")]
    ("pnd" - "vtk")[Label.raw("OR")]
    ("hwf" - "vtk")[Label.raw("OR")]
    ("y26" - "vqh")[Label.raw("AND")]
    ("x26" - "vqh")[Label.raw("AND")]
    ("vcs" - "jbp")[Label.raw("XOR")]
    ("dtj" - "jbp")[Label.raw("XOR")]
    ("x03" - "wgg")[Label.raw("AND")]
    ("y03" - "wgg")[Label.raw("AND")]
    ("rjv" - "brq")[Label.raw("OR")]
    ("fgf" - "brq")[Label.raw("OR")]
    ("vjn" - "trg")[Label.raw("AND")]
    ("tjg" - "trg")[Label.raw("AND")]
    ("cph" - "z05")[Label.raw("XOR")]
    ("qqd" - "z05")[Label.raw("XOR")]
    ("jbr" - "mvb")[Label.raw("AND")]
    ("ncd" - "mvb")[Label.raw("AND")]
    ("qvh" - "fbn")[Label.raw("AND")]
    ("wmd" - "fbn")[Label.raw("AND")]
    ("x25" - "cvf")[Label.raw("XOR")]
    ("y25" - "cvf")[Label.raw("XOR")]
    ("x39" - "rvc")[Label.raw("AND")]
    ("y39" - "rvc")[Label.raw("AND")]
    ("y44" - "ftc")[Label.raw("AND")]
    ("x44" - "ftc")[Label.raw("AND")]
    ("y36" - "grd")[Label.raw("XOR")]
    ("x36" - "grd")[Label.raw("XOR")]
    ("y03" - "kbg")[Label.raw("XOR")]
    ("x03" - "kbg")[Label.raw("XOR")]
    ("vvj" - "z27")[Label.raw("XOR")]
    ("bqv" - "z27")[Label.raw("XOR")]
    ("vbj" - "kqr")[Label.raw("AND")]
    ("chb" - "kqr")[Label.raw("AND")]
    ("twb" - "stw")[Label.raw("OR")]
    ("dtd" - "stw")[Label.raw("OR")]
    ("mnv" - "z13")[Label.raw("XOR")]
    ("hcg" - "z13")[Label.raw("XOR")]
    ("y26" - "dnj")[Label.raw("XOR")]
    ("x26" - "dnj")[Label.raw("XOR")]
    ("rkd" - "wrw")[Label.raw("OR")]
    ("rmp" - "wrw")[Label.raw("OR")]
    ("y22" - "tdc")[Label.raw("XOR")]
    ("x22" - "tdc")[Label.raw("XOR")]
    ("wvq" - "jsc")[Label.raw("AND")]
    ("tkt" - "jsc")[Label.raw("AND")]
    ("mjm" - "z08")[Label.raw("XOR")]
    ("gvw" - "z08")[Label.raw("XOR")]
    ("hvn" - "pck")[Label.raw("AND")]
    ("bdm" - "pck")[Label.raw("AND")]
    ("cbf" - "z09")[Label.raw("XOR")]
    ("vdr" - "z09")[Label.raw("XOR")]
    ("hdb" - "qtv")[Label.raw("OR")]
    ("hmb" - "qtv")[Label.raw("OR")]
    ("dvs" - "hwm")[Label.raw("OR")]
    ("mvd" - "hwm")[Label.raw("OR")]
    ("mqk" - "ncb")[Label.raw("AND")]
    ("nhk" - "ncb")[Label.raw("AND")]
    ("rfj" - "bst")[Label.raw("OR")]
    ("jgc" - "bst")[Label.raw("OR")]
    ("wrw" - "z28")[Label.raw("XOR")]
    ("hwh" - "z28")[Label.raw("XOR")]
    ("gdp" - "z07")[Label.raw("XOR")]
    ("stm" - "z07")[Label.raw("XOR")]
    ("stm" - "qgv")[Label.raw("AND")]
    ("gdp" - "qgv")[Label.raw("AND")]
    ("hff" - "z29")[Label.raw("XOR")]
    ("gdg" - "z29")[Label.raw("XOR")]
    ("y44" - "vbd")[Label.raw("XOR")]
    ("x44" - "vbd")[Label.raw("XOR")]
    ("tqq" - "tpn")[Label.raw("OR")]
    ("jjc" - "tpn")[Label.raw("OR")]
    ("qgm" - "cqg")[Label.raw("OR")]
    ("mvb" - "cqg")[Label.raw("OR")]
    ("dkg" - "z02")[Label.raw("XOR")]
    ("ghb" - "z02")[Label.raw("XOR")]
    ("wrw" - "pkq")[Label.raw("AND")]
    ("hwh" - "pkq")[Label.raw("AND")]
    ("hwm" - "z22")[Label.raw("AND")]
    ("tdc" - "z22")[Label.raw("AND")]
    ("x02" - "gws")[Label.raw("AND")]
    ("y02" - "gws")[Label.raw("AND")]
    ("jfp" - "ncd")[Label.raw("OR")]
    ("mpd" - "ncd")[Label.raw("OR")]
    ("y11" - "smr")[Label.raw("AND")]
    ("x11" - "smr")[Label.raw("AND")]
    ("hvd" - "vts")[Label.raw("AND")]
    ("bmb" - "vts")[Label.raw("AND")]
    ("kqr" - "qqd")[Label.raw("OR")]
    ("jsj" - "qqd")[Label.raw("OR")]
    ("y24" - "wgw")[Label.raw("XOR")]
    ("x24" - "wgw")[Label.raw("XOR")]
    ("stw" - "z30")[Label.raw("XOR")]
    ("bgs" - "z30")[Label.raw("XOR")]
    ("tpn" - "tpd")[Label.raw("AND")]
    ("wcn" - "tpd")[Label.raw("AND")]
    ("y19" - "pnd")[Label.raw("AND")]
    ("x19" - "pnd")[Label.raw("AND")]
    ("y38" - "dkn")[Label.raw("AND")]
    ("x38" - "dkn")[Label.raw("AND")]
    ("pkq" - "hff")[Label.raw("OR")]
    ("vbc" - "hff")[Label.raw("OR")]
    ("y31" - "ndd")[Label.raw("AND")]
    ("x31" - "ndd")[Label.raw("AND")]
    ("wwc" - "whj")[Label.raw("AND")]
    ("nvv" - "whj")[Label.raw("AND")]
    ("y14" - "drk")[Label.raw("XOR")]
    ("x14" - "drk")[Label.raw("XOR")]
    ("bst" - "jjc")[Label.raw("AND")]
    ("pkj" - "jjc")[Label.raw("AND")]
    ("sht" - "bnk")[Label.raw("OR")]
    ("fhh" - "bnk")[Label.raw("OR")]
    ("x05" - "cph")[Label.raw("XOR")]
    ("y05" - "cph")[Label.raw("XOR")]
    ("vts" - "tqv")[Label.raw("OR")]
    ("rvc" - "tqv")[Label.raw("OR")]
    ("x04" - "jsj")[Label.raw("AND")]
    ("y04" - "jsj")[Label.raw("AND")]
    ("wjv" - "z23")[Label.raw("XOR")]
    ("nbc" - "z23")[Label.raw("XOR")]
    ("y17" - "wcn")[Label.raw("XOR")]
    ("x17" - "wcn")[Label.raw("XOR")]
    ("x04" - "vbj")[Label.raw("XOR")]
    ("y04" - "vbj")[Label.raw("XOR")]
    ("y01" - "nqm")[Label.raw("AND")]
    ("x01" - "nqm")[Label.raw("AND")]
    ("x01" - "wwc")[Label.raw("XOR")]
    ("y01" - "wwc")[Label.raw("XOR")]
    ("vdr" - "sht")[Label.raw("AND")]
    ("cbf" - "sht")[Label.raw("AND")]
    ("jhm" - "dvs")[Label.raw("AND")]
    ("wst" - "dvs")[Label.raw("AND")]
    ("tpv" - "z14")[Label.raw("XOR")]
    ("drk" - "z14")[Label.raw("XOR")]
    ("cjm" - "z19")[Label.raw("XOR")]
    ("rws" - "z19")[Label.raw("XOR")]
    ("bqd" - "mtg")[Label.raw("OR")]
    ("hns" - "mtg")[Label.raw("OR")]
    ("x20" - "jtn")[Label.raw("XOR")]
    ("y20" - "jtn")[Label.raw("XOR")]
    ("x08" - "gvw")[Label.raw("AND")]
    ("y08" - "gvw")[Label.raw("AND")]
    ("cbc" - "z34")[Label.raw("XOR")]
    ("cqg" - "z34")[Label.raw("XOR")]
    ("rgt" - "rfj")[Label.raw("AND")]
    ("fbv" - "rfj")[Label.raw("AND")]
    ("wmd" - "z12")[Label.raw("XOR")]
    ("qvh" - "z12")[Label.raw("XOR")]
    ("x23" - "wjv")[Label.raw("XOR")]
    ("y23" - "wjv")[Label.raw("XOR")]
    ("y35" - "ppf")[Label.raw("AND")]
    ("x35" - "ppf")[Label.raw("AND")]
    ("x43" - "trf")[Label.raw("AND")]
    ("y43" - "trf")[Label.raw("AND")]
    ("fhg" - "z32")[Label.raw("XOR")]
    ("wnj" - "z32")[Label.raw("XOR")]
    ("x12" - "cmn")[Label.raw("AND")]
    ("y12" - "cmn")[Label.raw("AND")]
    ("y00" - "nvv")[Label.raw("AND")]
    ("x00" - "nvv")[Label.raw("AND")]
    ("tcw" - "hvn")[Label.raw("OR")]
    ("jms" - "hvn")[Label.raw("OR")]
    ("nhk" - "z31")[Label.raw("XOR")]
    ("mqk" - "z31")[Label.raw("XOR")]
    ("x07" - "stm")[Label.raw("XOR")]
    ("y07" - "stm")[Label.raw("XOR")]
    ("vgr" - "nph")[Label.raw("OR")]
    ("tjm" - "nph")[Label.raw("OR")]
    ("drk" - "ttr")[Label.raw("AND")]
    ("tpv" - "ttr")[Label.raw("AND")]
    ("x09" - "fhh")[Label.raw("AND")]
    ("y09" - "fhh")[Label.raw("AND")]
    ("x22" - "snh")[Label.raw("AND")]
    ("y22" - "snh")[Label.raw("AND")]
    ("wgw" - "z24")[Label.raw("XOR")]
    ("nph" - "z24")[Label.raw("XOR")]
    ("mtg" - "rrh")[Label.raw("AND")]
    ("vnm" - "rrh")[Label.raw("AND")]
    ("qvc" - "tps")[Label.raw("AND")]
    ("mms" - "tps")[Label.raw("AND")]
    ("x06" - "vnm")[Label.raw("XOR")]
    ("y06" - "vnm")[Label.raw("XOR")]
    ("tps" - "cjm")[Label.raw("OR")]
    ("jdr" - "cjm")[Label.raw("OR")]
    ("fbv" - "jgc")[Label.raw("XOR")]
    ("rgt" - "jgc")[Label.raw("XOR")]
    ("y41" - "wfd")[Label.raw("AND")]
    ("x41" - "wfd")[Label.raw("AND")]
    ("x19" - "rws")[Label.raw("XOR")]
    ("y19" - "rws")[Label.raw("XOR")]
    ("hcg" - "cfk")[Label.raw("AND")]
    ("mnv" - "cfk")[Label.raw("AND")]
    ("wsr" - "z38")[Label.raw("XOR")]
    ("shj" - "z38")[Label.raw("XOR")]
    ("brq" - "wtr")[Label.raw("AND")]
    ("jpt" - "wtr")[Label.raw("AND")]
    ("cjm" - "hwf")[Label.raw("AND")]
    ("rws" - "hwf")[Label.raw("AND")]
    ("y25" - "hmb")[Label.raw("AND")]
    ("x25" - "hmb")[Label.raw("AND")]
    ("y02" - "dkg")[Label.raw("XOR")]
    ("x02" - "dkg")[Label.raw("XOR")]
    ("y40" - "qsg")[Label.raw("AND")]
    ("x40" - "qsg")[Label.raw("AND")]
    ("bqv" - "rmp")[Label.raw("AND")]
    ("vvj" - "rmp")[Label.raw("AND")]
    ("hvd" - "z39")[Label.raw("XOR")]
    ("bmb" - "z39")[Label.raw("XOR")]
    ("y35" - "vcs")[Label.raw("XOR")]
    ("x35" - "vcs")[Label.raw("XOR")]
    ("x42" - "rjv")[Label.raw("AND")]
    ("y42" - "rjv")[Label.raw("AND")]
    ("x37" - "gdn")[Label.raw("AND")]
    ("y37" - "gdn")[Label.raw("AND")]
    ("tjg" - "z11")[Label.raw("XOR")]
    ("vjn" - "z11")[Label.raw("XOR")]
    ("qtv" - "z26")[Label.raw("XOR")]
    ("dnj" - "z26")[Label.raw("XOR")]
    ("jhm" - "z21")[Label.raw("XOR")]
    ("wst" - "z21")[Label.raw("XOR")]
    ("nwp" - "ggg")[Label.raw("OR")]
    ("gws" - "ggg")[Label.raw("OR")]
    ("y00" - "z00")[Label.raw("XOR")]
    ("x00" - "z00")[Label.raw("XOR")]
    ("mrq" - "wst")[Label.raw("OR")]
    ("wqs" - "wst")[Label.raw("OR")]
    ("x13" - "rsq")[Label.raw("AND")]
    ("y13" - "rsq")[Label.raw("AND")]
    ("ftr" - "hvd")[Label.raw("OR")]
    ("dkn" - "hvd")[Label.raw("OR")]
    ("jbr" - "z33")[Label.raw("XOR")]
    ("ncd" - "z33")[Label.raw("XOR")]
    ("x05" - "hns")[Label.raw("AND")]
    ("y05" - "hns")[Label.raw("AND")]
    ("rsq" - "tpv")[Label.raw("OR")]
    ("cfk" - "tpv")[Label.raw("OR")]
    ("mms" - "z18")[Label.raw("XOR")]
    ("qvc" - "z18")[Label.raw("XOR")]
    ("x27" - "rkd")[Label.raw("AND")]
    ("y27" - "rkd")[Label.raw("AND")]
    ("crv" - "hdb")[Label.raw("AND")]
    ("cvf" - "hdb")[Label.raw("AND")]
    ("cqg" - "rbm")[Label.raw("AND")]
    ("cbc" - "rbm")[Label.raw("AND")]
    ("pkj" - "z16")[Label.raw("XOR")]
    ("bst" - "z16")[Label.raw("XOR")]
    ("x28" - "vbc")[Label.raw("AND")]
    ("y28" - "vbc")[Label.raw("AND")]
    ("jsc" - "ngw")[Label.raw("OR")]
    ("wfd" - "ngw")[Label.raw("OR")]
    ("mjm" - "qqm")[Label.raw("AND")]
    ("gvw" - "qqm")[Label.raw("AND")]
    ("wnj" - "mpd")[Label.raw("AND")]
    ("fhg" - "mpd")[Label.raw("AND")]
    ("y15" - "rgt")[Label.raw("XOR")]
    ("x15" - "rgt")[Label.raw("XOR")]
    ("x20" - "mrq")[Label.raw("AND")]
    ("y20" - "mrq")[Label.raw("AND")]
    ("tkt" - "z41")[Label.raw("XOR")]
    ("wvq" - "z41")[Label.raw("XOR")]
    ("y13" - "mnv")[Label.raw("XOR")]
    ("x13" - "mnv")[Label.raw("XOR")]
    ("y24" - "nqr")[Label.raw("AND")]
    ("x24" - "nqr")[Label.raw("AND")]
    ("wtr" - "jvs")[Label.raw("OR")]
    ("trf" - "jvs")[Label.raw("OR")]
    ("ggg" - "jcf")[Label.raw("AND")]
    ("kbg" - "jcf")[Label.raw("AND")]
    ("x36" - "jms")[Label.raw("AND")]
    ("y36" - "jms")[Label.raw("AND")]
    ("x29" - "dtd")[Label.raw("AND")]
    ("y29" - "dtd")[Label.raw("AND")]
    ("ksk" - "fgf")[Label.raw("AND")]
    ("ngw" - "fgf")[Label.raw("AND")]
    ("x11" - "vjn")[Label.raw("XOR")]
    ("y11" - "vjn")[Label.raw("XOR")]
    ("tpn" - "z17")[Label.raw("XOR")]
    ("wcn" - "z17")[Label.raw("XOR")]
    ("y43" - "jpt")[Label.raw("XOR")]
    ("x43" - "jpt")[Label.raw("XOR")]
    ("vbd" - "jjn")[Label.raw("AND")]
    ("jvs" - "jjn")[Label.raw("AND")]
    ("nnr" - "tkt")[Label.raw("OR")]
    ("qsg" - "tkt")[Label.raw("OR")]
    ("x27" - "bqv")[Label.raw("XOR")]
    ("y27" - "bqv")[Label.raw("XOR")]
    ("x28" - "hwh")[Label.raw("XOR")]
    ("y28" - "hwh")[Label.raw("XOR")]
    ("x09" - "cbf")[Label.raw("XOR")]
    ("y09" - "cbf")[Label.raw("XOR")]
    ("vcs" - "qrg")[Label.raw("AND")]
    ("dtj" - "qrg")[Label.raw("AND")]
    ("x34" - "cbc")[Label.raw("XOR")]
    ("y34" - "cbc")[Label.raw("XOR")]
    ("ghb" - "nwp")[Label.raw("AND")]
    ("dkg" - "nwp")[Label.raw("AND")]
    ("y37" - "bdm")[Label.raw("XOR")]
    ("x37" - "bdm")[Label.raw("XOR")]
    ("x38" - "shj")[Label.raw("XOR")]
    ("y38" - "shj")[Label.raw("XOR")]
    ("hjt" - "crv")[Label.raw("OR")]
    ("nqr" - "crv")[Label.raw("OR")]
    ("vbd" - "z44")[Label.raw("XOR")]
    ("jvs" - "z44")[Label.raw("XOR")]
    ("fbn" - "hcg")[Label.raw("OR")]
    ("cmn" - "hcg")[Label.raw("OR")]
    ("x06" - "dqs")[Label.raw("AND")]
    ("y06" - "dqs")[Label.raw("AND")]
    ("y15" - "z15")[Label.raw("AND")]
    ("x15" - "z15")[Label.raw("AND")]
    ("x33" - "jbr")[Label.raw("XOR")]
    ("y33" - "jbr")[Label.raw("XOR")]
    ("y21" - "jhm")[Label.raw("XOR")]
    ("x21" - "jhm")[Label.raw("XOR")]
    ("snh" - "nbc")[Label.raw("OR")]
    ("drg" - "nbc")[Label.raw("OR")]
    ("y18" - "mms")[Label.raw("XOR")]
    ("x18" - "mms")[Label.raw("XOR")]
    ("vqh" - "vvj")[Label.raw("OR")]
    ("gbg" - "vvj")[Label.raw("OR")]
    ("y21" - "mvd")[Label.raw("AND")]
    ("x21" - "mvd")[Label.raw("AND")]
    ("qrg" - "z35")[Label.raw("OR")]
    ("ppf" - "z35")[Label.raw("OR")]
    ("y10" - "ktf")[Label.raw("AND")]
    ("x10" - "ktf")[Label.raw("AND")]
    ("x16" - "tqq")[Label.raw("AND")]
    ("y16" - "tqq")[Label.raw("AND")]
    ("tdc" - "drg")[Label.raw("XOR")]
    ("hwm" - "drg")[Label.raw("XOR")]
    ("wwc" - "z01")[Label.raw("XOR")]
    ("nvv" - "z01")[Label.raw("XOR")]
    ("x17" - "djn")[Label.raw("AND")]
    ("y17" - "djn")[Label.raw("AND")]
    ("jpt" - "z43")[Label.raw("XOR")]
    ("brq" - "z43")[Label.raw("XOR")]
    ("smr" - "wmd")[Label.raw("OR")]
    ("trg" - "wmd")[Label.raw("OR")]
    ("x16" - "pkj")[Label.raw("XOR")]
    ("y16" - "pkj")[Label.raw("XOR")]
    ("x29" - "gdg")[Label.raw("XOR")]
    ("y29" - "gdg")[Label.raw("XOR")]
    ("bgs" - "dmm")[Label.raw("AND")]
    ("stw" - "dmm")[Label.raw("AND")]
    ("ngw" - "z42")[Label.raw("XOR")]
    ("ksk" - "z42")[Label.raw("XOR")]
}

val file = Graphviz.fromGraph(a).render(Format.DOT).toFile(File("output2.dot"))

// %%
import java.io.File

val dotFile = File("dot.dot")

val gates = input.substringAfter("\n\n").lines().map { it.split(Regex(" -> | ")) }

val list = mutableListOf<String>()
gates.forEach {
    var one = "\"${it[0]}\" -> \"${it[3]}\" [\"label\"=\"${it[1]}\"];"
    var two = "\"${it[2]}\" -> \"${it[3]}\" [\"label\"=\"${it[1]}\"];"
    list.add(one)
    list.add(two)
}

var dot = list.joinToString("\n","digraph {\n", "\n}")
//
//dot = "digraph {\n" + list.first() +  "\n}"


dotFile.writeText(dot)

Graphviz.fromFile(dotFile).render(Format.PNG).toFile(File("output3.png"))
// Out:
// output3.png
